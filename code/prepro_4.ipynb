# %%
import pandas as pd
import numpy as np
import requests
import json
import bs4 as bs
import urllib.request
from tmdbv3api import TMDb, Movie
from utils import *

# %% [markdown]
# ## Note: In this notebook we will build a whole pipeline based on the previous notebook - prepro_3

# %%
link_2019 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2019"
link_2020 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2020"
link_2021 = "https://en.wikipedia.org/wiki/List_of_American_films_of_2021"

# %% [markdown]
# ### Scrape the data from Wikipedia

# %%
def scrape_data_to_df(link):
    source = urllib.request.urlopen(link).read()
    soup = bs.BeautifulSoup(source, "lxml")
    tables = soup.find_all("table", class_="wikitable sortable")
    jan_mar_title = soup.find(id="January–March").get_text()
    apr_jun_title = soup.find(id="April–June").get_text()
    jul_sep_title = soup.find(id="July–September").get_text()
    oct_dec_title = soup.find(id="October–December").get_text()
    print(f"Scraped movies from the following months: {jan_mar_title}, {apr_jun_title}, {jul_sep_title}, {oct_dec_title}.")
    print(f"{len(tables)} tables in total.")
    
    return tables
    #tables_to_df(tables)
    #print(df)

# %%
scraped_data = scrape_data_to_df(link_2019)
# Out:
# Scraped movies from the following months: January–March, April–June, July–September, October–December.
# 4 tables in total.

# %% [markdown]
# ### Create a dataframe from the scrapped tables

# %%
def tables_to_df(tables):
    df1 = pd.read_html(str(tables[0]))[0]
    df2 = pd.read_html(str(tables[1]))[0]
    df3 = pd.read_html(str(tables[2]))[0]
    df4 = pd.read_html(str(tables[3]))[0]
    
    df = df1.append(df2.append(df3.append(df4, ignore_index=True), ignore_index=True), ignore_index=True)
    return df

# %%
df = tables_to_df(scraped_data)

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 237  20th Century Fox / Blue Sky Studios / Chernin ...
# 238            Columbia Pictures / Regency Enterprises
# 239  Universal Pictures / DreamWorks Pictures / Ent...
# 240          Warner Bros. Pictures / Participant Media
# 241                                               Neon
#
#                                          Cast and crew   Ref.
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 237  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]
# 238  Greta Gerwig (director/screenplay); Saoirse Ro...  [221]
# 239  Sam Mendes (director/screenplay); Krysty Wilso...  [222]
# 240  Destin Daniel Cretton (director/screenplay), A...  [223]
# 241  Chinonye Chukwu (director/screenplay); Alfre W...  [224]
#
# [242 rows x 6 columns]

# %% [markdown]
# ### Getting the genre from TMDb API

# %%
df["genres"] = df["Title"].map(lambda x: get_genre(str(x)))

# %%
df
# Out:
#       Opening  Opening.1              Title  \
# 0     JANUARY          4        Escape Room
# 1     JANUARY          4         Rust Creek
# 2     JANUARY          4   American Hangman
# 3     JANUARY         11   A Dog's Way Home
# 4     JANUARY         11         The Upside
# ..        ...        ...                ...
# 237  DECEMBER         25  Spies in Disguise
# 238  DECEMBER         25       Little Women
# 239  DECEMBER         25               1917
# 240  DECEMBER         25         Just Mercy
# 241  DECEMBER         27           Clemency
#
#                                     Production company  \
# 0                                    Columbia Pictures
# 1                                            IFC Films
# 2                          Hangman Justice Productions
# 3                                    Columbia Pictures
# 4                                    STX Entertainment
# ..                                                 ...
# 237  20th Century Fox / Blue Sky Studios / Chernin ...
# 238            Columbia Pictures / Regency Enterprises
# 239  Universal Pictures / DreamWorks Pictures / Ent...
# 240          Warner Bros. Pictures / Participant Media
# 241                                               Neon
#
#                                          Cast and crew   Ref.  \
# 0    Adam Robitel (director); Bragi F. Schut, Maria...    [2]
# 1    Jen McGowan (director); Julie Lipson (screenpl...    [3]
# 2    Wilson Coneybeare (director/screenplay); Donal...    [4]
# 3    Charles Martin Smith (director); W. Bruce Came...    [5]
# 4    Neil Burger (director); Jon Hartmere (screenpl...    [6]
# ..                                                 ...    ...
# 237  Nick Bruno, Troy Quane (directors); Brad Copel...  [132]
# 238  Greta Gerwig (director/screenplay); Saoirse Ro...  [221]
# 239  Sam Mendes (director/screenplay); Krysty Wilso...  [222]
# 240  Destin Daniel Cretton (director/screenplay), A...  [223]
# 241  Chinonye Chukwu (director/screenplay); Alfre W...  [224]
#
#                                        genres
# 0    Thriller Action Mystery Adventure Horror
# 1                              Thriller Drama
# 2                                    Thriller
# 3                      Drama Adventure Family
# 4                                Comedy Drama
# ..                                        ...
# 237  Animation Action Adventure Comedy Family
# 238                             Drama Romance
# 239                 War Drama Action Thriller
# 240                       Drama Crime History
# 241                                     Drama
#
# [242 rows x 7 columns]

# %% [markdown]
# ### Filtering the director and the top 3 actors of each movie

# %%
df["director_name"] = df["Cast and crew"].map(lambda x: get_director(str(x)))

# %%
#Retrun to this after you finished
#df["director_name"].unique()

# %%
df["actor_1_name"] = df["Cast and crew"].map(lambda x: get_actor1(str(x)))

# %%
#Retrun to this after you finished
#df["actor_1_name"].unique()

# %%
df["actor_2_name"] = df["Cast and crew"].map(lambda x: get_actor2(str(x)))

# %%
#Retrun to this after you finished
#df["actor_2_name"].unique()

# %%
df["actor_3_name"] = df["Cast and crew"].map(lambda x: get_actor3(str(x)))

# %% [markdown]
# ### Feature selection

# %%
feature_list = ["Title", "genres", "director_name", "actor_1_name", "actor_2_name", "actor_3_name"]

# %%
df_2019 = df[feature_list]
df_2019
# Out:
#                  Title                                    genres  \
# 0          Escape Room  Thriller Action Mystery Adventure Horror
# 1           Rust Creek                            Thriller Drama
# 2     American Hangman                                  Thriller
# 3     A Dog's Way Home                    Drama Adventure Family
# 4           The Upside                              Comedy Drama
# ..                 ...                                       ...
# 237  Spies in Disguise  Animation Action Adventure Comedy Family
# 238       Little Women                             Drama Romance
# 239               1917                 War Drama Action Thriller
# 240         Just Mercy                       Drama Crime History
# 241           Clemency                                     Drama
#
#               director_name                                   actor_1_name  \
# 0              Adam Robitel                                 Taylor Russell
# 1               Jen McGowan                              Hermione Corfield
# 2         Wilson Coneybeare                              Donald Sutherland
# 3      Charles Martin Smith                            Bryce Dallas Howard
# 4               Neil Burger                                 Bryan Cranston
# ..                      ...                                            ...
# 237  Nick Bruno, Troy Quane                                     Will Smith
# 238            Greta Gerwig                                  Saoirse Ronan
# 239              Sam Mendes                                  George MacKay
# 240   Destin Daniel Cretton  Andrew Lanham (screenplay); Michael B. Jordan
# 241         Chinonye Chukwu                                  Alfre Woodard
#
#              actor_2_name      actor_3_name
# 0            Logan Miller  Deborah Ann Woll
# 1             Jay Paulson      Sean O'Bryan
# 2      Vincent Kartheiser     Oliver Dennis
# 3      Edward James Olmos   Alexandra Shipp
# 4              Kevin Hart     Nicole Kidman
# ..                    ...               ...
# 237           Tom Holland     Rashida Jones
# 238           Emma Watson     Florence Pugh
# 239  Dean-Charles Chapman       Mark Strong
# 240            Jamie Foxx       Brie Larson
# 241        Wendell Pierce       Aldis Hodge
#
# [242 rows x 6 columns]

# %% [markdown]
# ### Renaming column name and movie names to be consistent with previous datasets

# %%
df_2019 = df_2019.rename(columns={"Title": "movie_title"})

# %%
df_2019["movie_title"] = df_2019["movie_title"].str.lower()

# %% [markdown]
# ### Dropping missing values

# %%
df_2019.isnull().sum()
# Out:
# movie_title      0
# genres           0
# director_name    0
# actor_1_name     0
# actor_2_name     0
# actor_3_name     0
# dtype: int64

# %% [markdown]
# ### Combine cast and genre columns for future steps in Tfidf vectorizer

# %%
df_2019["combined_info"] = df_2019["director_name"] + " " + df_2019["actor_1_name"] + " " +  df_2019["actor_2_name"] + " " + df_2019["actor_3_name"] + " " + df_2019["genres"]

# %%
df_2019["combined_info"].unique()
# Out:
# array(['Adam Robitel Taylor Russell Logan Miller Deborah Ann Woll Thriller Action Mystery Adventure Horror',
#        "Jen McGowan Hermione Corfield Jay Paulson Sean O'Bryan Thriller Drama",
#        'Wilson Coneybeare Donald Sutherland Vincent Kartheiser Oliver Dennis Thriller',
#        'Charles Martin Smith Bryce Dallas Howard Edward James Olmos Alexandra Shipp Drama Adventure Family',
#        'Neil Burger Bryan Cranston Kevin Hart Nicole Kidman Comedy Drama',
#        'Jeffrey Nachmanoff Keanu Reeves None None Science Fiction Thriller',
#        'Batán Silva Natalia Dyer Kyra Sedgwick Tim Daly Drama Family Thriller Science Fiction',
#        'M. Night Shyamalan James McAvoy Bruce Willis Samuel L. Jackson Thriller Drama Science Fiction',
#        'Vicky Jewson Noomi Rapace Sophie Nélisse Indira Varma Action Thriller',
#        'Henry Dunham James Badge Dale Brian Geraghty None Drama Thriller Mystery',
#        'Timothy Woodward Jr. Lin Shaye Michael Welch Melissa Bolona Horror',
#        'Joe Cornish Louis Ashbourne Serkis Dean Chaumoo Tom Taylor Action Adventure Fantasy Family',
#        'Steven Knight Matthew McConaughey Anne Hathaway Jason Clarke Thriller Mystery Drama',
#        'Grant Sputore None None None Science Fiction Thriller',
#        'Andrew Patterson None None None Mystery Science Fiction Thriller',
#        'Catherine Hardwicke Gina Rodriguez Ismael Cruz Córdova Anthony Mackie Action',
#        'Dan Gilroy Jake Gyllenhaal Rene Russo Toni Collette Thriller Mystery Horror',
#        'Nicolas Pesce Christopher Abbott Mia Wasikowska Laia Costa Thriller Horror Mystery',
#        'Mike Mitchell Chris Pratt Elizabeth Banks Tiffany Haddish Action Adventure Animation Comedy Family',
#        'Adam Shankman Taraji P. Henson Tracy Morgan Max Greenfield Comedy Romance',
#        'Hans Petter Moland Liam Neeson Tom Bateman Tom Jackson Action Crime Thriller',
#        'Steven Soderbergh André Holland Zazie Beetz Melvin Gregg Drama',
#        'Nicholas McCarthy Taylor Schilling Peter Mooney Colm Feore Horror Thriller',
#        'Todd Strauss-Schulson Rebel Wilson Liam Hemsworth Adam DeVine Comedy Fantasy Romance',
#        'Christopher Landon Jessica Rothe Israel Broussard Phi Vu Comedy Horror Science Fiction',
#        'Robert Rodriguez Rosa Salazar Christoph Waltz Jennifer Connelly Action Science Fiction Adventure',
#        'Dean DeBlois Jay Baruchel America Ferrera Cate Blanchett Animation Family Adventure',
#        'Stephen Merchant Florence Pugh Lena Headey Nick Frost Comedy',
